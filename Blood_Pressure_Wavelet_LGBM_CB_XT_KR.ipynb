# %%
import numpy as np
from scipy.ndimage import uniform_filter1d
from scipy.signal import detrend


def find_peaks_original(x, scale=None, debug=False):
    """Find peaks in quasi-periodic noisy signals using AMPD algorithm.
    Automatic Multi-Scale Peak Detection originally proposed in
    "An Efficient Algorithm for Automatic Peak Detection in
    Noisy Periodic and Quasi-Periodic Signals", Algorithms 2012, 5, 588-603
    https://doi.org/10.1109/ICRERA.2016.7884365
    Optimized implementation by Igor Gotlibovych, 2018
    Parameters
    ----------
    x : ndarray
        1-D array on which to find peaks
    scale : int, optional
        specify maximum scale window size of (2 * scale + 1)
    debug : bool, optional
        if set to True, return the Local Scalogram Matrix, `LSM`,
        and scale with most local maxima, `l`,
        together with peak locations
    Returns
    -------
    pks: ndarray
        The ordered array of peak indices found in `x`
    """
    x = detrend(x)
    N = len(x)
    L = N // 2
    if scale:
        L = min(scale, L)

    # create LSM matix
    LSM = np.zeros((L, N), dtype=bool)
    for k in np.arange(1, L):
        LSM[k - 1, k:N - k] = (
            (x[0:N - 2 * k] < x[k:N - k]) & (x[k:N - k] > x[2 * k:N])
        )

    # Find scale with most maxima
    G = LSM.sum(axis=1)
    l_scale = np.argmax(G)

    # find peaks that persist on all scales up to l
    pks_logical = np.min(LSM[0:l_scale, :], axis=0)
    pks = np.flatnonzero(pks_logical)
    if debug:
        return pks, LSM, l_scale
    return pks


def find_peaks(x, scale=None, debug=False):
    """Find peaks in quasi-periodic noisy signals using AMPD algorithm.
    Extended implementation handles peaks near start/end of the signal.
    Optimized implementation by Igor Gotlibovych, 2018
    Parameters
    ----------
    x : ndarray
        1-D array on which to find peaks
    scale : int, optional
        specify maximum scale window size of (2 * scale + 1)
    debug : bool, optional
        if set to True, return the Local Scalogram Matrix, `LSM`,
        weigted number of maxima, 'G',
        and scale at which G is maximized, `l`,
        together with peak locations
    Returns
    -------
    pks: ndarray
        The ordered array of peak indices found in `x`
    """
    x = detrend(x)
    N = len(x)
    L = N // 2
    if scale:
        L = min(scale, L)

    # create LSM matix
    LSM = np.ones((L, N), dtype=bool)
    for k in np.arange(1, L + 1):
        LSM[k - 1, 0:N - k] &= (x[0:N - k] > x[k:N]
                                )  # compare to right neighbours
        LSM[k - 1, k:N] &= (x[k:N] > x[0:N - k])  # compare to left neighbours

    # Find scale with most maxima
    G = LSM.sum(axis=1)
    G = G * np.arange(
        N // 2, N // 2 - L, -1
    )  # normalize to adjust for new edge regions
    l_scale = np.argmax(G)

    # find peaks that persist on all scales up to l
    pks_logical = np.min(LSM[0:l_scale, :], axis=0)
    pks = np.flatnonzero(pks_logical)
    if debug:
        return pks, LSM, G, l_scale
    return pks


def find_peaks_adaptive(x, window=None, debug=False):
    """Find peaks in quasi-periodic noisy signals using ASS-AMPD algorithm.
    Adaptive Scale Selection Automatic Multi-Scale Peak Detection,
    an extension of AMPD -
    "An Efficient Algorithm for Automatic Peak Detection in
    Noisy Periodic and Quasi-Periodic Signals", Algorithms 2012, 5, 588-603
    https://doi.org/10.1109/ICRERA.2016.7884365
    Optimized implementation by Igor Gotlibovych, 2018
    Parameters
    ----------
    x : ndarray
        1-D array on which to find peaks
    window : int, optional
        sliding window size for adaptive scale selection
    debug : bool, optional
        if set to True, return the Local Scalogram Matrix, `LSM`,
        and `adaptive_scale`,
        together with peak locations
    Returns
    -------
    pks: ndarray
        The ordered array of peak indices found in `x`
    """
    x = detrend(x)
    N = len(x)
    if not window:
        window = N
    if window > N:
        window = N
    L = window // 2

    # create LSM matix
    LSM = np.ones((L, N), dtype=bool)
    for k in np.arange(1, L + 1):
        LSM[k - 1, 0:N - k] &= (x[0:N - k] > x[k:N]
                                )  # compare to right neighbours
        LSM[k - 1, k:N] &= (x[k:N] > x[0:N - k])  # compare to left neighbours

    # Create continuos adaptive LSM
    ass_LSM = uniform_filter1d(LSM * window, window, axis=1, mode='nearest')
    normalization = np.arange(L, 0, -1)  # scale normalization weight
    ass_LSM = ass_LSM * normalization.reshape(-1, 1)

    # Find adaptive scale at each point
    adaptive_scale = ass_LSM.argmax(axis=0)

    # construct reduced LSM
    LSM_reduced = LSM[:adaptive_scale.max(), :]
    mask = (np.indices(LSM_reduced.shape)[0] > adaptive_scale
            )  # these elements are outside scale of interest
    LSM_reduced[mask] = 1

    # find peaks that persist on all scales up to l
    pks_logical = np.min(LSM_reduced, axis=0)
    pks = np.flatnonzero(pks_logical)
    if debug:
        return pks, ass_LSM, adaptive_scale
    return pks

# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
import torch.utils.data as Data
import torchvision.datasets
import torchvision.transforms
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import glob
# from pyampd.ampd import find_peaks


device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

import matplotlib.pyplot as plt


import joblib
# Out:
# cpu

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip gdrive/My\ Drive/archive.zip
# Out:
# Archive:  gdrive/My Drive/archive.zip
#   inflating: Samples/rec_1.csv
#   inflating: Samples/rec_10.csv
#   inflating: Samples/rec_100.csv
#   inflating: Samples/rec_101.csv
#   inflating: Samples/rec_102.csv
#   inflating: Samples/rec_103.csv
#   inflating: Samples/rec_104.csv
#   inflating: Samples/rec_105.csv
#   inflating: Samples/rec_106.csv
#   inflating: Samples/rec_107.csv
#   inflating: Samples/rec_108.csv
#   inflating: Samples/rec_109.csv
#   inflating: Samples/rec_11.csv
#   inflating: Samples/rec_110.csv
#   inflating: Samples/rec_111.csv
#   inflating: Samples/rec_112.csv
#   inflating: Samples/rec_113.csv
#   inflating: Samples/rec_114.csv
#   inflating: Samples/rec_115.csv
#   inflating: Samples/rec_116.csv
#   inflating: Samples/rec_117.csv
#   inflating: Samples/rec_118.csv
#   inflating: Samples/rec_119.csv
#   inflating: Samples/rec_12.csv
#   inflating: Samples/rec_120.csv
#   inflating: Samples/rec_121.csv
#   inflating: Samples/rec_122.csv
#   inflating: Samples/rec_123.csv
#   inflating: Samples/rec_124.csv
#   inflating: Samples/rec_125.csv
#   inflating: Samples/rec_126.csv
#   inflating: Samples/rec_127.csv
#   inflating: Samples/rec_128.csv
#   inflating: Samples/rec_129.csv
#   inflating: Samples/rec_13.csv
#   inflating: Samples/rec_130.csv
#   inflating: Samples/rec_131.csv
#   inflating: Samples/rec_132.csv
#   inflating: Samples/rec_133.csv
#   inflating: Samples/rec_134.csv
#   inflating: Samples/rec_75.csv
#   inflating: Samples/rec_76.csv
#   inflating: Samples/rec_77.csv
#   inflating: Samples/rec_78.csv
#   inflating: Samples/rec_79.csv
#   inflating: Samples/rec_8.csv
#   inflating: Samples/rec_80.csv
#   inflating: Samples/rec_81.csv
#   inflating: Samples/rec_82.csv
#   inflating: Samples/rec_83.csv
#   inflating: Samples/rec_84.csv
#   inflating: Samples/rec_85.csv
#   inflating: Samples/rec_86.csv
#   inflating: Samples/rec_87.csv
#   inflating: Samples/rec_88.csv
#   inflating: Samples/rec_89.csv
#   inflating: Samples/rec_9.csv
#   inflating: Samples/rec_90.csv
#   inflating: Samples/rec_91.csv
#   inflating: Samples/rec_92.csv
#   inflating: Samples/rec_93.csv
#   inflating: Samples/rec_94.csv
#   inflating: Samples/rec_95.csv
#   inflating: Samples/rec_96.csv
#   inflating: Samples/rec_97.csv
#   inflating: Samples/rec_98.csv
#   inflating: Samples/rec_99.csv
#   inflating: part_1.mat
#   inflating: part_10.mat
#   inflating: part_11.mat
#   inflating: part_12.mat
#   inflating: part_2.mat
#   inflating: part_3.mat
#   inflating: part_4.mat
#   inflating: part_5.mat
#   inflating: part_6.mat
#   inflating: part_7.mat
#   inflating: part_8.mat
#   inflating: part_9.mat

# %%
PPG_datas = []
ABP_datas = []
ECG_datas = []
i = 0
for name in glob.glob('./Samples/*.csv'):
    raw_training_data = pd.read_csv(name, header=None)
    raw_training_data = np.array(raw_training_data)
    #print(raw_training_data.shape)
    PPG_data = raw_training_data[0]
    ABP_data = raw_training_data[1]
    ECG_data = raw_training_data[2]

    PPG_datas.append(PPG_data)
    ABP_datas.append(ABP_data)
    ECG_datas.append(ECG_data)
    # i = i + 1
 #   print(i)
#     if (i == 100):
#         break

PPG_datas = np.array(PPG_datas)
ABP_datas = np.array(ABP_datas)
ECG_datas = np.array(ECG_datas)
# raw_training_data.head()
# Out:
# <ipython-input-5-cafb0a523fd7>:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   PPG_datas = np.array(PPG_datas)
# <ipython-input-5-cafb0a523fd7>:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ABP_datas = np.array(ABP_datas)
# <ipython-input-5-cafb0a523fd7>:23: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ECG_datas = np.array(ECG_datas)

# %%
import pywt
from sklearn.decomposition import PCA

def generate_wavelet_vector(X, wavelet_family, decomposition_level):
    coefficients = pywt.wavedec(X, wavelet_family, level=decomposition_level)
    vector = np.array([])
    for coeffs in coefficients:
        vector = np.concatenate((vector, coeffs))
    return vector

# %%
SAMPLE_FREQ = 125

# %%
wavelet_family = 'db4'
decomposition_level = 5

wavelet_vectors = []
SBP_data = []
DBP_data = []
MAP_data = []

for j in range(len(PPG_datas)):
    sec_15 = 15 * SAMPLE_FREQ
    PPG_data = PPG_datas[j]
    ABP_data = ABP_datas[j]
    PPG_peaks = find_peaks(PPG_data, scale=SAMPLE_FREQ)
    for i in range(2, PPG_peaks.shape[0]):
        X = PPG_data[PPG_peaks[i - 1]:PPG_peaks[i]]
        if len(X) < SAMPLE_FREQ:
            wavelet_vector = generate_wavelet_vector(X, wavelet_family, decomposition_level)

            SBP = np.max(ABP_data[PPG_peaks[i - 1]:PPG_peaks[i - 1] + sec_15])
            DBP = np.min(ABP_data[PPG_peaks[i - 1]:PPG_peaks[i - 1] + sec_15])
            MAP = SBP / 3 + 2 * DBP / 3

            wavelet_vectors.append(wavelet_vector)
            SBP_data.append(SBP)
            DBP_data.append(DBP)
            MAP_data.append(MAP)
# Out:
# /usr/local/lib/python3.10/dist-packages/pywt/_multilevel.py:43: UserWarning: Level value of 5 is too high: all coefficients will experience boundary effects.
#   warnings.warn(

# %%
wavelet_vectors = np.array(wavelet_vectors)
SBP_data = np.array(SBP_data)
DBP_data = np.array(DBP_data)
MAP_data = np.array(MAP_data)

print(wavelet_vectors.shape)
print(SBP_data.shape)

# Find the maximum length of the wavelet vectors
max_length = max([len(vector) for vector in wavelet_vectors])

# Pad the wavelet vectors with zeros to make them uniform length
padded_wavelet_vectors = []
for vector in wavelet_vectors:
    padded_vector = np.pad(vector, (0, max_length - len(vector)), mode='constant')
    padded_wavelet_vectors.append(padded_vector)

padded_wavelet_vectors = np.array(padded_wavelet_vectors)
# Out:
# <ipython-input-9-6f3e639507bb>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   wavelet_vectors = np.array(wavelet_vectors)
# (196625,)
# (196625,)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=43)
pca_wavelet_vectors = pca.fit_transform(padded_wavelet_vectors)

print(pca_wavelet_vectors.shape)
# Out:
# (196625, 43)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, SBP_train, SBP_test, DBP_train, DBP_test, MAP_train, MAP_test = train_test_split(
    pca_wavelet_vectors, SBP_data, DBP_data, MAP_data, test_size=0.1, random_state=42)

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(range(len(PPG_datas[0][:500])), PPG_datas[0][:500])
plt.title('PPG signal')

fig = plt.figure()
ax = plt.axes()
ax.plot(range(len(ABP_datas[0][:500])), ABP_datas[0][:500])
plt.title('ABP signal')

fig = plt.figure()
ax = plt.axes()
ax.plot(range(len(ECG_datas[0][:500])), ECG_datas[0][:500])
plt.title('ECG signal')

fig = plt.figure()
ax = plt.axes()
ax.plot(range(len(wavelet_vectors[0])), wavelet_vectors[0])
plt.title('wavelet vector')

fig = plt.figure()
ax = plt.axes()
ax.plot(range(len(padded_wavelet_vectors[0])), padded_wavelet_vectors[0])
plt.title('padded_wavelet vector')

fig = plt.figure()
ax = plt.axes()
ax.plot(range(len(pca_wavelet_vectors[0])), pca_wavelet_vectors[0])
plt.title('wavelet vector after PCA')
# Out:
# Text(0.5, 1.0, 'wavelet vector after PCA')

# %%
def AAMI_standard(predict, test):
    total = len(predict)
    ME = np.mean(predict - test)
    MAE = np.mean(np.abs(predict-test))
    SD = np.std(predict-test)

    return total, ME, MAE, SD

def BHS_standard(predict, test):
    total = len(predict)
    mm5 = np.sum(np.abs(predict-test)<=5)
    mm10 = np.sum(np.abs(predict-test)<=10)
    mm15 = np.sum(np.abs(predict-test)<=15)
    return total, mm5, mm10, mm15

# %%
import lightgbm as lgb

# LightGBM Regressor for SBP
lgb_SBP = lgb.LGBMRegressor(n_estimators=100, learning_rate=0.1)
print('start fitting...')
lgb_SBP.fit(x_train, SBP_train)
print('finish fitting...')


# LightGBM Regressor for DBP
lgb_DBP = lgb.LGBMRegressor(n_estimators=100, learning_rate=0.1)
print('start fitting...')
lgb_DBP.fit(x_train, DBP_train)
print('finish fitting...')


# LightGBM Regressor for MAP
lgb_MAP = lgb.LGBMRegressor(n_estimators=100, learning_rate=0.1)
print('start fitting...')
lgb_MAP.fit(x_train, MAP_train)
print('finish fitting...')
# Out:
# start fitting...
# finish fitting...
# start fitting...
# finish fitting...
# start fitting...
# finish fitting...

# %%
import time
start_time = time.time()


lgb_SBP_predict = lgb_SBP.predict(x_test)
print('finish predicting...')

lgb_DBP_predict = lgb_DBP.predict(x_test)
print('finish predicting...')

lgb_MAP_predict = lgb_MAP.predict(x_test)
print('finish predicting...')

print('LightGBM Regression')

total, ME, MAE, SD = AAMI_standard(lgb_SBP_predict, SBP_test)
print()
print()
print('----------------SBP-----------------')
print()
print('-------------AAMI standard----------')
print('ME             MAE             SD           total')
print('%.3f         %.3f         %.3f          %d' % (ME, MAE, SD, total))

total, mm5, mm10, mm15 = BHS_standard(lgb_SBP_predict, SBP_test)
print()
print('-------------BHS standard------------')
print('<5mmHg        <10mmHg        <15mmHg        total')
print('%d            %d           %d          %d' % (mm5, mm10, mm15, total))
print('%.3f%s        %.3f%s       %.3f%s         %d' % (mm5/total*100, '%', mm10/total*100, '%', mm15/total*100, '%', total))

total, ME, MAE, SD = AAMI_standard(lgb_DBP_predict, DBP_test)
print()
print()
print('----------------DBP-----------------')
print()
print('-------------AAMI standard----------')
print('ME             MAE             SD           total')
print('%.3f         %.3f         %.3f          %d' % (ME, MAE, SD, total))

total, mm5, mm10, mm15 = BHS_standard(lgb_DBP_predict, DBP_test)
print()
print('-------------BHS standard------------')
print('<5mmHg        <10mmHg        <15mmHg        total')
print('%d            %d           %d          %d' % (mm5, mm10, mm15, total))
print('%.3f%s        %.3f%s       %.3f%s         %d' % (mm5/total*100, '%', mm10/total*100, '%', mm15/total*100, '%', total))

total, ME, MAE, SD = AAMI_standard(lgb_MAP_predict, MAP_test)
print()
print()
print('----------------MAP-----------------')
print()
print('-------------AAMI standard----------')
print('ME             MAE             SD           total')
print('%.3f         %.3f         %.3f          %d' % (ME, MAE, SD, total))

total, mm5, mm10, mm15 = BHS_standard(lgb_MAP_predict, MAP_test)
print()
print('-------------BHS standard------------')
print('<5mmHg        <10mmHg        <15mmHg        total')
print('%d            %d           %d          %d' % (mm5, mm10, mm15, total))
print('%.3f%s        %.3f%s       %.3f%s         %d' % (mm5/total*100, '%', mm10/total*100, '%', mm15/total*100, '%', total))

# Record the end time
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time

# Print the elapsed time
print("Time taken:", elapsed_time, "seconds")
# Out:
# finish predicting...
# finish predicting...
# finish predicting...
# LightGBM Regression
#
#
# ----------------SBP-----------------
#
# -------------AAMI standard----------
# ME             MAE             SD           total
# 0.018         10.617         14.624          19663
#
# -------------BHS standard------------
# <5mmHg        <10mmHg        <15mmHg        total
# 7049            11888           14886          19663
# 35.849%        60.459%       75.706%         19663
#
#
# ----------------DBP-----------------
#
# -------------AAMI standard----------
# ME             MAE             SD           total
# 0.011         4.957         7.317          19663
#
# -------------BHS standard------------
# <5mmHg        <10mmHg        <15mmHg        total
# 12772            17382           18785          19663
# 64.954%        88.400%       95.535%         19663
#
#
# ----------------MAP-----------------
#
# -------------AAMI standard----------
# ME             MAE             SD           total
# 0.021         5.690         7.864          19663
#
# -------------BHS standard------------
# <5mmHg        <10mmHg        <15mmHg        total
# 11393            16337           18355          19663
# 57.941%        83.085%       93.348%         19663
# Time taken: 0.5383274555206299 seconds

# %%
print('LightGBM Regression')

lgb_SBP_cc = np.corrcoef(lgb_SBP_predict, SBP_test)
lgb_DBP_cc = np.corrcoef(lgb_DBP_predict, DBP_test)
lgb_MAP_cc = np.corrcoef(lgb_MAP_predict, MAP_test)
print()
print()
print('------------Correlation Coefficient-------------')
print()
print('SBP: %.3f' % (lgb_SBP_cc[0, 1]))
print()
print('DBP: %.3f' % (lgb_DBP_cc[0, 1]))
print()
print('MAP: %.3f' % (lgb_MAP_cc[0, 1]))
# Out:
# LightGBM Regression
#
#
# ------------Correlation Coefficient-------------
#
# SBP: 0.755
#
# DBP: 0.712
#
# MAP: 0.740

# %%
# !pip install catboost
from catboost import CatBoostRegressor

# CatBoost Regressor for SBP
cat_SBP = CatBoostRegressor(n_estimators=100, learning_rate=0.1)
print('start fitting...')
cat_SBP.fit(x_train, SBP_train)
print('finish fitting...')

# CatBoost Regressor for DBP
cat_DBP = CatBoostRegressor(n_estimators=100, learning_rate=0.1)
print('start fitting...')
cat_DBP.fit(x_train, DBP_train)
print('finish fitting...')


# CatBoost Regressor for MAP
cat_MAP = CatBoostRegressor(n_estimators=100, learning_rate=0.1)
print('start fitting...')
cat_MAP.fit(x_train, MAP_train)
print('finish fitting...')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting catboost
#   Downloading catboost-1.2-cp310-cp310-manylinux2014_x86_64.whl (98.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.2)
# Installing collected packages: catboost
# Successfully installed catboost-1.2
# start fitting...
# 0:	learn: 21.6887746	total: 108ms	remaining: 10.7s
# 1:	learn: 21.2296418	total: 161ms	remaining: 7.89s
# 2:	learn: 20.8307798	total: 219ms	remaining: 7.06s
# 3:	learn: 20.5099812	total: 284ms	remaining: 6.82s
# 4:	learn: 20.2091992	total: 343ms	remaining: 6.53s
# 5:	learn: 19.9547360	total: 397ms	remaining: 6.22s
# 6:	learn: 19.7133237	total: 456ms	remaining: 6.06s
# 7:	learn: 19.5201499	total: 514ms	remaining: 5.91s
# 8:	learn: 19.3542853	total: 581ms	remaining: 5.87s
# 9:	learn: 19.1824593	total: 632ms	remaining: 5.69s
# 10:	learn: 19.0289365	total: 688ms	remaining: 5.57s
# 11:	learn: 18.9053905	total: 747ms	remaining: 5.48s
# 12:	learn: 18.7647794	total: 820ms	remaining: 5.49s
# 13:	learn: 18.6594527	total: 869ms	remaining: 5.34s
# 14:	learn: 18.5554778	total: 942ms	remaining: 5.34s
# 10:	learn: 9.3002347	total: 628ms	remaining: 5.08s
# 11:	learn: 9.2538269	total: 689ms	remaining: 5.05s
# 12:	learn: 9.2025695	total: 751ms	remaining: 5.02s
# 13:	learn: 9.1682404	total: 803ms	remaining: 4.93s
# 14:	learn: 9.1305394	total: 862ms	remaining: 4.89s
# 15:	learn: 9.0965750	total: 917ms	remaining: 4.81s
# 16:	learn: 9.0552439	total: 972ms	remaining: 4.75s
# 17:	learn: 9.0180375	total: 1.02s	remaining: 4.65s
# 18:	learn: 8.9911571	total: 1.07s	remaining: 4.58s
# 19:	learn: 8.9677602	total: 1.13s	remaining: 4.52s
# 20:	learn: 8.9433399	total: 1.18s	remaining: 4.46s
# 21:	learn: 8.9066388	total: 1.24s	remaining: 4.41s
# 22:	learn: 8.8844937	total: 1.3s	remaining: 4.35s
# 23:	learn: 8.8580150	total: 1.35s	remaining: 4.29s
# 24:	learn: 8.8340858	total: 1.43s	remaining: 4.29s
# 25:	learn: 8.8164105	total: 1.48s	remaining: 4.2s
# 26:	learn: 8.7936316	total: 1.53s	remaining: 4.13s
# 27:	learn: 8.7704623	total: 1.58s	remaining: 4.07s
# 28:	learn: 8.7500430	total: 1.64s	remaining: 4.02s
# 29:	learn: 8.7254990	total: 1.7s	remaining: 3.96s
# 30:	learn: 8.7081561	total: 1.75s	remaining: 3.89s
# 31:	learn: 8.6941166	total: 1.79s	remaining: 3.81s
# 32:	learn: 8.6797604	total: 1.83s	remaining: 3.72s
# 33:	learn: 8.6604665	total: 1.88s	remaining: 3.66s
# 34:	learn: 8.6418640	total: 1.94s	remaining: 3.61s
# 35:	learn: 8.6188794	total: 2s	remaining: 3.55s
# 36:	learn: 8.5995757	total: 2.05s	remaining: 3.49s
# 37:	learn: 8.5855555	total: 2.1s	remaining: 3.43s
# 38:	learn: 8.5747867	total: 2.15s	remaining: 3.37s
# 39:	learn: 8.5614412	total: 2.2s	remaining: 3.3s
# 40:	learn: 8.5473267	total: 2.25s	remaining: 3.23s
# 41:	learn: 8.5320912	total: 2.31s	remaining: 3.19s
# 42:	learn: 8.5185777	total: 2.36s	remaining: 3.12s
# 43:	learn: 8.5035437	total: 2.41s	remaining: 3.07s
# 44:	learn: 8.4863517	total: 2.48s	remaining: 3.03s
# 45:	learn: 8.4694901	total: 2.53s	remaining: 2.97s
# 46:	learn: 8.4538887	total: 2.58s	remaining: 2.91s
# 47:	learn: 8.4380088	total: 2.64s	remaining: 2.86s
# 48:	learn: 8.4284501	total: 2.68s	remaining: 2.79s
# 49:	learn: 8.4177993	total: 2.74s	remaining: 2.74s
# 50:	learn: 8.4021479	total: 2.8s	remaining: 2.69s
# 51:	learn: 8.3852995	total: 2.85s	remaining: 2.63s
# 52:	learn: 8.3728752	total: 2.9s	remaining: 2.57s
# 53:	learn: 8.3591729	total: 2.95s	remaining: 2.51s
# 54:	learn: 8.3489599	total: 3s	remaining: 2.46s
# 55:	learn: 8.3400344	total: 3.05s	remaining: 2.4s
# 56:	learn: 8.3299705	total: 3.1s	remaining: 2.34s
# 57:	learn: 8.3143073	total: 3.15s	remaining: 2.28s
# 58:	learn: 8.2997523	total: 3.21s	remaining: 2.23s
# 59:	learn: 8.2844286	total: 3.27s	remaining: 2.18s
# 60:	learn: 8.2760530	total: 3.32s	remaining: 2.12s
# 61:	learn: 8.2652768	total: 3.37s	remaining: 2.07s
# 62:	learn: 8.2577561	total: 3.42s	remaining: 2.01s
# 63:	learn: 8.2444679	total: 3.48s	remaining: 1.96s
# 64:	learn: 8.2337342	total: 3.54s	remaining: 1.91s
# 65:	learn: 8.2257333	total: 3.59s	remaining: 1.85s
# 66:	learn: 8.2127445	total: 3.65s	remaining: 1.8s
# 67:	learn: 8.2020923	total: 3.7s	remaining: 1.74s
# 68:	learn: 8.1911639	total: 3.76s	remaining: 1.69s
# 69:	learn: 8.1803512	total: 3.81s	remaining: 1.63s
# 70:	learn: 8.1708425	total: 3.87s	remaining: 1.58s
# 71:	learn: 8.1585581	total: 3.93s	remaining: 1.53s
# 72:	learn: 8.1468871	total: 3.98s	remaining: 1.47s
# 73:	learn: 8.1383473	total: 4.04s	remaining: 1.42s
# 74:	learn: 8.1272804	total: 4.09s	remaining: 1.36s
# 75:	learn: 8.1187760	total: 4.14s	remaining: 1.31s
# 76:	learn: 8.1113434	total: 4.19s	remaining: 1.25s
# 77:	learn: 8.1034380	total: 4.23s	remaining: 1.19s
# 78:	learn: 8.0972347	total: 4.28s	remaining: 1.14s
# 79:	learn: 8.0904970	total: 4.33s	remaining: 1.08s
# 80:	learn: 8.0828793	total: 4.39s	remaining: 1.03s
# 81:	learn: 8.0742969	total: 4.44s	remaining: 975ms
# 82:	learn: 8.0671482	total: 4.51s	remaining: 924ms
# 83:	learn: 8.0611493	total: 4.56s	remaining: 869ms
# 84:	learn: 8.0505361	total: 4.62s	remaining: 816ms
# 85:	learn: 8.0438488	total: 4.67s	remaining: 760ms
# 86:	learn: 8.0387549	total: 4.72s	remaining: 705ms
# 87:	learn: 8.0305023	total: 4.78s	remaining: 651ms
# 88:	learn: 8.0233927	total: 4.83s	remaining: 597ms
# 89:	learn: 8.0153665	total: 4.88s	remaining: 542ms
# 90:	learn: 8.0051098	total: 4.94s	remaining: 488ms
# 91:	learn: 7.9980558	total: 5s	remaining: 435ms
# 92:	learn: 7.9902350	total: 5.05s	remaining: 380ms
# 93:	learn: 7.9837879	total: 5.1s	remaining: 326ms
# 94:	learn: 7.9761614	total: 5.16s	remaining: 271ms
# 95:	learn: 7.9708014	total: 5.21s	remaining: 217ms
# 96:	learn: 7.9638011	total: 5.26s	remaining: 163ms
# 97:	learn: 7.9549169	total: 5.32s	remaining: 109ms
# 98:	learn: 7.9501160	total: 5.37s	remaining: 54.2ms
# 99:	learn: 7.9430665	total: 5.42s	remaining: 0us
# finish fitting...
# start fitting...
# 0:	learn: 11.3781955	total: 117ms	remaining: 11.6s
# 1:	learn: 11.2147202	total: 227ms	remaining: 11.1s
# 2:	learn: 11.0735458	total: 347ms	remaining: 11.2s
# 3:	learn: 10.9523148	total: 451ms	remaining: 10.8s
# 4:	learn: 10.8414406	total: 557ms	remaining: 10.6s
# 5:	learn: 10.7407867	total: 673ms	remaining: 10.5s
# 53:	learn: 9.1544237	total: 4.61s	remaining: 3.92s
# 54:	learn: 9.1300650	total: 4.66s	remaining: 3.82s
# 55:	learn: 9.1117184	total: 4.72s	remaining: 3.71s
# 56:	learn: 9.0991240	total: 4.78s	remaining: 3.6s
# 57:	learn: 9.0815306	total: 4.84s	remaining: 3.51s
# 58:	learn: 9.0677014	total: 4.89s	remaining: 3.4s
# 59:	learn: 9.0551257	total: 4.94s	remaining: 3.29s
# 60:	learn: 9.0378912	total: 5s	remaining: 3.19s
# 61:	learn: 9.0233287	total: 5.05s	remaining: 3.09s
# 62:	learn: 9.0097826	total: 5.1s	remaining: 3s
# 63:	learn: 8.9891440	total: 5.15s	remaining: 2.9s
# 64:	learn: 8.9754558	total: 5.21s	remaining: 2.8s
# 65:	learn: 8.9643626	total: 5.25s	remaining: 2.71s
# 66:	learn: 8.9526984	total: 5.31s	remaining: 2.62s
# 67:	learn: 8.9441059	total: 5.37s	remaining: 2.52s
# 68:	learn: 8.9347735	total: 5.41s	remaining: 2.43s
# 69:	learn: 8.9218488	total: 5.46s	remaining: 2.34s
# 70:	learn: 8.9116762	total: 5.52s	remaining: 2.26s
# 71:	learn: 8.9016269	total: 5.57s	remaining: 2.17s
# 72:	learn: 8.8890234	total: 5.63s	remaining: 2.08s
# 73:	learn: 8.8755425	total: 5.68s	remaining: 2s
# 74:	learn: 8.8648181	total: 5.74s	remaining: 1.91s
# 75:	learn: 8.8491913	total: 5.8s	remaining: 1.83s
# 76:	learn: 8.8417610	total: 5.86s	remaining: 1.75s
# 77:	learn: 8.8274360	total: 5.91s	remaining: 1.67s
# 78:	learn: 8.8169607	total: 5.97s	remaining: 1.59s
# 79:	learn: 8.8051787	total: 6.02s	remaining: 1.5s
# 80:	learn: 8.7948359	total: 6.07s	remaining: 1.42s
# 81:	learn: 8.7860859	total: 6.12s	remaining: 1.34s
# 82:	learn: 8.7691657	total: 6.18s	remaining: 1.26s
# 83:	learn: 8.7594431	total: 6.24s	remaining: 1.19s
# 84:	learn: 8.7508670	total: 6.29s	remaining: 1.11s
# 85:	learn: 8.7401857	total: 6.36s	remaining: 1.03s
# 86:	learn: 8.7306965	total: 6.41s	remaining: 958ms
# 87:	learn: 8.7214729	total: 6.48s	remaining: 884ms
# 88:	learn: 8.7133104	total: 6.54s	remaining: 809ms
# 89:	learn: 8.7069313	total: 6.58s	remaining: 732ms
# 90:	learn: 8.6937553	total: 6.64s	remaining: 657ms
# 91:	learn: 8.6836170	total: 6.71s	remaining: 583ms
# 92:	learn: 8.6733768	total: 6.77s	remaining: 509ms
# 93:	learn: 8.6644704	total: 6.82s	remaining: 435ms
# 94:	learn: 8.6520759	total: 6.89s	remaining: 363ms
# 95:	learn: 8.6431107	total: 6.95s	remaining: 289ms
# 96:	learn: 8.6373603	total: 7s	remaining: 216ms
# 97:	learn: 8.6278711	total: 7.05s	remaining: 144ms
# 98:	learn: 8.6209625	total: 7.1s	remaining: 71.7ms
# 99:	learn: 8.6115764	total: 7.14s	remaining: 0us
# finish fitting...

# %%
import time
start_time = time.time()



cat_SBP_predict = cat_SBP.predict(x_test)
print('finish predicting...')

cat_DBP_predict = cat_DBP.predict(x_test)
print('finish predicting...')

cat_MAP_predict = cat_MAP.predict(x_test)
print('finish predicting...')

print('CatBoost Regression')

total, ME, MAE, SD = AAMI_standard(cat_SBP_predict, SBP_test)
print()
print()
print('----------------SBP-----------------')
print()
print('-------------AAMI standard----------')
print('ME             MAE             SD           total')
print('%.3f         %.3f         %.3f          %d' % (ME, MAE, SD, total))

total, mm5, mm10, mm15 = BHS_standard(cat_SBP_predict, SBP_test)
print()
print('-------------BHS standard------------')
print('<5mmHg        <10mmHg        <15mmHg        total')
print('%d            %d           %d          %d' % (mm5, mm10, mm15, total))
print('%.3f%s        %.3f%s       %.3f%s         %d' % (mm5/total*100, '%', mm10/total*100, '%', mm15/total*100, '%', total))

total, ME, MAE, SD = AAMI_standard(cat_DBP_predict, DBP_test)
print()
print()
print('----------------DBP-----------------')
print()
print('-------------AAMI standard----------')
print('ME             MAE             SD           total')
print('%.3f         %.3f         %.3f          %d' % (ME, MAE, SD, total))

total, mm5, mm10, mm15 = BHS_standard(cat_DBP_predict, DBP_test)
print()
print('-------------BHS standard------------')
print('<5mmHg        <10mmHg        <15mmHg        total')
print('%d            %d           %d          %d' % (mm5, mm10, mm15, total))
print('%.3f%s        %.3f%s       %.3f%s         %d' % (mm5/total*100, '%', mm10/total*100, '%', mm15/total*100, '%', total))

total, ME, MAE, SD = AAMI_standard(cat_MAP_predict, MAP_test)
print()
print()
print('----------------MAP-----------------')
print()
print('-------------AAMI standard----------')
print('ME             MAE             SD           total')
print('%.3f         %.3f         %.3f          %d' % (ME, MAE, SD, total))

total, mm5, mm10, mm15 = BHS_standard(cat_MAP_predict, MAP_test)
print()
print('-------------BHS standard------------')
print('<5mmHg        <10mmHg        <15mmHg        total')
print('%d            %d           %d          %d' % (mm5, mm10, mm15, total))
print('%.3f%s        %.3f%s       %.3f%s         %d' % (mm5/total*100, '%', mm10/total*100, '%', mm15/total*100, '%', total))

# Record the end time
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time

# Print the elapsed time
print("Time taken:", elapsed_time, "seconds")
# Out:
# finish predicting...
# finish predicting...
# finish predicting...
# CatBoost Regression
#
#
# ----------------SBP-----------------
#
# -------------AAMI standard----------
# ME             MAE             SD           total
# -0.006         11.821         15.838          19663
#
# -------------BHS standard------------
# <5mmHg        <10mmHg        <15mmHg        total
# 6161            10932           13962          19663
# 31.333%        55.597%       71.006%         19663
#
#
# ----------------DBP-----------------
#
# -------------AAMI standard----------
# ME             MAE             SD           total
# -0.015         5.508         8.121          19663
#
# -------------BHS standard------------
# <5mmHg        <10mmHg        <15mmHg        total
# 11835            16923           18611          19663
# 60.189%        86.065%       94.650%         19663
#
#
# ----------------MAP-----------------
#
# -------------AAMI standard----------
# ME             MAE             SD           total
# -0.006         6.440         8.730          19663
#
# -------------BHS standard------------
# <5mmHg        <10mmHg        <15mmHg        total
# 10171            15640           17948          19663
# 51.727%        79.540%       91.278%         19663
# Time taken: 0.7406537532806396 seconds

# %%
print('CatBoost Regression')

cat_SBP_cc = np.corrcoef(cat_SBP_predict, SBP_test)
cat_DBP_cc = np.corrcoef(cat_DBP_predict, DBP_test)
cat_MAP_cc = np.corrcoef(cat_MAP_predict, MAP_test)
print()
print()
print('------------Correlation Coefficient-------------')
print()
print('SBP: %.3f' % (cat_SBP_cc[0, 1]))
print()
print('DBP: %.3f' % (cat_DBP_cc[0, 1]))
print()
print('MAP: %.3f' % (cat_MAP_cc[0, 1]))
# Out:
# CatBoost Regression
#
#
# ------------Correlation Coefficient-------------
#
# SBP: 0.706
#
# DBP: 0.628
#
# MAP: 0.668

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_SBP = KNeighborsRegressor(n_neighbors=5)
print('start fitting...')
knn_SBP.fit(x_train, SBP_train)
print('finish fitting...')


knn_DBP = KNeighborsRegressor(n_neighbors=5)
print('start fitting...')
knn_DBP.fit(x_train, DBP_train)
print('finish fitting...')


knn_MAP = KNeighborsRegressor(n_neighbors=5)
print('start fitting...')
knn_MAP.fit(x_train, MAP_train)
print('finish fitting...')
# Out:
# start fitting...
# finish fitting...
# start fitting...
# finish fitting...
# start fitting...
# finish fitting...

# %%
import time
start_time = time.time()

knn_SBP_predict = knn_SBP.predict(x_test)
print('finish predicting...')

knn_DBP_predict = knn_DBP.predict(x_test)
print('finish predicting...')

knn_MAP_predict = knn_MAP.predict(x_test)
print('finish predicting...')


print('k-Nearest Neighbors Regression')

total, ME, MAE, SD = AAMI_standard(knn_SBP_predict, SBP_test)
print()
print()
print('----------------SBP-----------------')
print()
print('-------------AAMI standard----------')
print('ME             MAE             SD           total')
print('%.3f         %.3f         %.3f          %d' % (ME, MAE, SD, total))

total, mm5, mm10, mm15 = BHS_standard(knn_SBP_predict, SBP_test)
print()
print('-------------BHS standard------------')
print('<5mmHg        <10mmHg        <15mmHg        total')
print('%d            %d           %d          %d' % (mm5, mm10, mm15, total))
print('%.3f%s        %.3f%s       %.3f%s         %d' % (mm5/total*100, '%', mm10/total*100, '%', mm15/total*100, '%', total))

total, ME, MAE, SD = AAMI_standard(knn_DBP_predict, DBP_test)
print()
print()
print('----------------DBP-----------------')
print()
print('-------------AAMI standard----------')
print('ME             MAE             SD           total')
print('%.3f         %.3f         %.3f          %d' % (ME, MAE, SD, total))

total, mm5, mm10, mm15 = BHS_standard(knn_DBP_predict, DBP_test)
print()
print('-------------BHS standard------------')
print('<5mmHg        <10mmHg        <15mmHg        total')
print('%d            %d           %d          %d' % (mm5, mm10, mm15, total))
print('%.3f%s        %.3f%s       %.3f%s         %d' % (mm5/total*100, '%', mm10/total*100, '%', mm15/total*100, '%', total))

total, ME, MAE, SD = AAMI_standard(knn_MAP_predict, MAP_test)
print()
print()
print('----------------MAP-----------------')
print()
print('-------------AAMI standard----------')
print('ME             MAE             SD           total')
print('%.3f         %.3f         %.3f          %d' % (ME, MAE, SD, total))

total, mm5, mm10, mm15 = BHS_standard(knn_MAP_predict, MAP_test)
print()
print('-------------BHS standard------------')
print('<5mmHg        <10mmHg        <15mmHg        total')
print('%d            %d           %d          %d' % (mm5, mm10, mm15, total))
print('%.3f%s        %.3f%s       %.3f%s         %d' % (mm5/total*100, '%', mm10/total*100, '%', mm15/total*100, '%', total))

# Record the end time
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time

# Print the elapsed time
print("Time taken:", elapsed_time, "seconds")
# Out:
# finish predicting...
# finish predicting...
# finish predicting...
# k-Nearest Neighbors Regression
#
#
# ----------------SBP-----------------
#
# -------------AAMI standard----------
# ME             MAE             SD           total
# -0.503         9.766         14.781          19663
#
# -------------BHS standard------------
# <5mmHg        <10mmHg        <15mmHg        total
# 9133            13022           15304          19663
# 46.448%        66.226%       77.831%         19663
#
#
# ----------------DBP-----------------
#
# -------------AAMI standard----------
# ME             MAE             SD           total
# -0.101         4.660         7.629          19663
#
# -------------BHS standard------------
# <5mmHg        <10mmHg        <15mmHg        total
# 13696            17237           18584          19663
# 69.654%        87.662%       94.513%         19663
#
#
# ----------------MAP-----------------
#
# -------------AAMI standard----------
# ME             MAE             SD           total
# -0.235         5.279         8.105          19663
#
# -------------BHS standard------------
# <5mmHg        <10mmHg        <15mmHg        total
# 12653            16418           18150          19663
# 64.349%        83.497%       92.305%         19663
# Time taken: 115.65461492538452 seconds

# %%
print('k-Nearest Neighbors Regression')

knn_SBP_cc = np.corrcoef(knn_SBP_predict, SBP_test)
knn_DBP_cc = np.corrcoef(knn_DBP_predict, DBP_test)
knn_MAP_cc = np.corrcoef(knn_MAP_predict, MAP_test)
print()
print()
print('------------Correlation Coefficient-------------')
print()
print('SBP: %.3f' % (knn_SBP_cc[0, 1]))
print()
print('DBP: %.3f' % (knn_DBP_cc[0, 1]))
print()
print('MAP: %.3f' % (knn_MAP_cc[0, 1]))
# Out:
# k-Nearest Neighbors Regression
#
#
# ------------Correlation Coefficient-------------
#
# SBP: 0.748
#
# DBP: 0.678
#
# MAP: 0.718

# %%
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_absolute_error

etr_SBP = ExtraTreesRegressor(n_estimators=100, random_state=42)
print('start fitting...')
etr_SBP.fit(x_train, SBP_train)
print('finish fitting...')

etr_DBP = ExtraTreesRegressor(n_estimators=100, random_state=42)
print('start fitting...')
etr_DBP.fit(x_train, DBP_train)
print('finish fitting...')


etr_MAP = ExtraTreesRegressor(n_estimators=100, random_state=42)
print('start fitting...')
etr_MAP.fit(x_train, MAP_train)
print('finish fitting...')
# Out:
# start fitting...
# finish fitting...
# start fitting...
# finish fitting...
# start fitting...
# finish fitting...

# %%
import time
start_time = time.time()

etr_SBP_predict = etr_SBP.predict(x_test)
print('finish predicting...')

etr_DBP_predict = etr_DBP.predict(x_test)
print('finish predicting...')

etr_MAP_predict = etr_MAP.predict(x_test)
print('finish predicting...')


print('Extra Trees Regression')

total, ME, MAE, SD = AAMI_standard(etr_SBP_predict, SBP_test)
print()
print()
print('----------------SBP-----------------')
print()
print('-------------AAMI standard----------')
print('ME             MAE             SD           total')
print('%.3f         %.3f         %.3f          %d' % (ME, MAE, SD, total))

total, mm5, mm10, mm15 = BHS_standard(etr_SBP_predict, SBP_test)
print()
print('-------------BHS standard------------')
print('<5mmHg        <10mmHg        <15mmHg        total')
print('%d            %d           %d          %d' % (mm5, mm10, mm15, total))
print('%.3f%s        %.3f%s       %.3f%s         %d' % (mm5/total*100, '%', mm10/total*100, '%', mm15/total*100, '%', total))

total, ME, MAE, SD = AAMI_standard(etr_DBP_predict, DBP_test)
print()
print()
print('----------------DBP-----------------')
print()
print('-------------AAMI standard----------')
print('ME             MAE             SD           total')
print('%.3f         %.3f         %.3f          %d' % (ME, MAE, SD, total))

total, mm5, mm10, mm15 = BHS_standard(etr_DBP_predict, DBP_test)
print()
print('-------------BHS standard------------')
print('<5mmHg        <10mmHg        <15mmHg        total')
print('%d            %d           %d          %d' % (mm5, mm10, mm15, total))
print('%.3f%s        %.3f%s       %.3f%s         %d' % (mm5/total*100, '%', mm10/total*100, '%', mm15/total*100, '%', total))

total, ME, MAE, SD = AAMI_standard(etr_MAP_predict, MAP_test)
print()
print()
print('----------------MAP-----------------')
print()
print('-------------AAMI standard----------')
print('ME             MAE             SD           total')
print('%.3f         %.3f         %.3f          %d' % (ME, MAE, SD, total))

total, mm5, mm10, mm15 = BHS_standard(etr_MAP_predict, MAP_test)
print()
print('-------------BHS standard------------')
print('<5mmHg        <10mmHg        <15mmHg        total')
print('%d            %d           %d          %d' % (mm5, mm10, mm15, total))
print('%.3f%s        %.3f%s       %.3f%s         %d' % (mm5/total*100, '%', mm10/total*100, '%', mm15/total*100, '%', total))

# Record the end time
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time

# Print the elapsed time
print("Time taken:", elapsed_time, "seconds")
# Out:
# finish predicting...
# finish predicting...
# finish predicting...
# Extra Trees Regression
#
#
# ----------------SBP-----------------
#
# -------------AAMI standard----------
# ME             MAE             SD           total
# 0.007         7.439         11.569          19663
#
# -------------BHS standard------------
# <5mmHg        <10mmHg        <15mmHg        total
# 10847            14882           16778          19663
# 55.165%        75.685%       85.328%         19663
#
#
# ----------------DBP-----------------
#
# -------------AAMI standard----------
# ME             MAE             SD           total
# 0.180         3.517         5.779          19663
#
# -------------BHS standard------------
# <5mmHg        <10mmHg        <15mmHg        total
# 15368            18257           19121          19663
# 78.157%        92.850%       97.244%         19663
#
#
# ----------------MAP-----------------
#
# -------------AAMI standard----------
# ME             MAE             SD           total
# 0.097         3.892         6.067          19663
#
# -------------BHS standard------------
# <5mmHg        <10mmHg        <15mmHg        total
# 14628            17820           18950          19663
# 74.394%        90.627%       96.374%         19663
# Time taken: 6.339606523513794 seconds

# %%
print('Extra Trees Regression')

etr_SBP_cc = np.corrcoef(etr_SBP_predict, SBP_test)
etr_DBP_cc = np.corrcoef(etr_DBP_predict, DBP_test)
etr_MAP_cc = np.corrcoef(etr_MAP_predict, MAP_test)
print()
print()
print('------------Correlation Coefficient-------------')
print()
print('SBP: %.3f' % (etr_SBP_cc[0, 1]))
print()
print('DBP: %.3f' % (etr_DBP_cc[0, 1]))
print()
print('MAP: %.3f' % (etr_MAP_cc[0, 1]))
# Out:
# Extra Trees Regression
#
#
# ------------Correlation Coefficient-------------
#
# SBP: 0.857
#
# DBP: 0.831
#
# MAP: 0.856
